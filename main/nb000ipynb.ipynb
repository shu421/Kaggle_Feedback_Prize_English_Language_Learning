# %%
import sys
from pathlib import Path

# %%
import sys
from pathlib import Path

class Config:
    if 'google.colab' in sys.modules:
        # %cd drive/MyDrive/Kaggle_Feedback-Prize-Evaluating-Student-Writing/
    input = Path('../input/')
    nb_name = 'nb000'
# Out:
# /content/drive/MyDrive/Kaggle_Feedback-Prize-Evaluating-Student-Writing
